# %%
import pandas as pd

# %%
calendar = pd.read_csv("../data/raw/calendar.csv")

# %%
calendar.head()
# Out:
#           version https://git-lfs.github.com/spec/v1
# 0                                       <<<<<<< HEAD
# 1  oid sha256:d12b5914ef03e66649adf5dd9e996e66022...
# 2                                        size 103469
# 3                                            =======
# 4  oid sha256:ca67ec6704084302882b8e97148abb174e7...

# %%
import pandas as pd

calendar = pd.read_csv("../data/raw/calendar.csv")

print(calendar.columns.tolist())
# Out:
# ['date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year', 'd', 'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2', 'snap_CA', 'snap_TX', 'snap_WI']

# %%
import pandas as pd
calendar = pd.read_csv("../data/raw/calendar.csv")
print(calendar.columns.tolist())
# Out:
# ['date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year', 'd', 'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2', 'snap_CA', 'snap_TX', 'snap_WI']

# %%
import pandas as pd

calendar = pd.read_csv("../data/raw/calendar.csv")

# %%
print(calendar.columns.tolist())
# Out:
# ['date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year', 'd', 'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2', 'snap_CA', 'snap_TX', 'snap_WI']

# %%
calendar["date"] = pd.to_datetime(calendar["date"])

calendar["year"] = calendar["date"].dt.year
calendar["month"] = calendar["date"].dt.month
calendar["week"] = calendar["date"].dt.isocalendar().week
calendar["day"] = calendar["date"].dt.day
calendar["weekday"] = calendar["date"].dt.day_name()

# %%
calendar["date"].head()
# Out:
# 0   2011-01-29
# 1   2011-01-30
# 2   2011-01-31
# 3   2011-02-01
# 4   2011-02-02
# Name: date, dtype: datetime64[ns]

# %%
calendar["date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
calendar["date"] = pd.to_datetime(calendar["date"])

# %%
calendar["date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
calendar["year"] = calendar["date"].dt.year

# %%
calendar[["date", "year"]].head()
# Out:
#         date  year
# 0 2011-01-29  2011
# 1 2011-01-30  2011
# 2 2011-01-31  2011
# 3 2011-02-01  2011
# 4 2011-02-02  2011

# %%
calendar["month"] = calendar["date"].dt.month

# %%
calendar[["date", "month"]].head()
# Out:
#         date  month
# 0 2011-01-29      1
# 1 2011-01-30      1
# 2 2011-01-31      1
# 3 2011-02-01      2
# 4 2011-02-02      2

# %%
calendar["week"] = calendar["date"].dt.isocalendar().week

# %%
calendar[["date", "week"]].head()
# Out:
#         date  week
# 0 2011-01-29     4
# 1 2011-01-30     4
# 2 2011-01-31     5
# 3 2011-02-01     5
# 4 2011-02-02     5

# %%
calendar["day"] = calendar["date"].dt.day

# %%
calendar[["date", "day"]].head()
# Out:
#         date  day
# 0 2011-01-29   29
# 1 2011-01-30   30
# 2 2011-01-31   31
# 3 2011-02-01    1
# 4 2011-02-02    2

# %%
calendar["weekday"] = calendar["date"].dt.day_name()

# %%
calendar[["date", "weekday"]].head()
# Out:
#         date    weekday
# 0 2011-01-29   Saturday
# 1 2011-01-30     Sunday
# 2 2011-01-31     Monday
# 3 2011-02-01    Tuesday
# 4 2011-02-02  Wednesday

# %%
calendar[[
    "event_name_1",
    "event_type_1",
    "event_name_2",
    "event_type_2"
]].head(20)
# Out:
#      event_name_1 event_type_1 event_name_2 event_type_2
# 0             NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN
# 5             NaN          NaN          NaN          NaN
# 6             NaN          NaN          NaN          NaN
# 7             NaN          NaN          NaN          NaN
# 8       SuperBowl     Sporting          NaN          NaN
# 9             NaN          NaN          NaN          NaN
# 10            NaN          NaN          NaN          NaN
# 11            NaN          NaN          NaN          NaN
# 12            NaN          NaN          NaN          NaN
# 13            NaN          NaN          NaN          NaN
# 14            NaN          NaN          NaN          NaN
# ...

# %%
event_columns = [
    "event_name_1",
    "event_type_1",
    "event_name_2",
    "event_type_2"
]

calendar[event_columns] = calendar[event_columns].fillna("No Event")

# %%
calendar[event_columns].head(20)
# Out:
#      event_name_1 event_type_1 event_name_2 event_type_2
# 0        No Event     No Event     No Event     No Event
# 1        No Event     No Event     No Event     No Event
# 2        No Event     No Event     No Event     No Event
# 3        No Event     No Event     No Event     No Event
# 4        No Event     No Event     No Event     No Event
# 5        No Event     No Event     No Event     No Event
# 6        No Event     No Event     No Event     No Event
# 7        No Event     No Event     No Event     No Event
# 8       SuperBowl     Sporting     No Event     No Event
# 9        No Event     No Event     No Event     No Event
# 10       No Event     No Event     No Event     No Event
# 11       No Event     No Event     No Event     No Event
# 12       No Event     No Event     No Event     No Event
# 13       No Event     No Event     No Event     No Event
# 14       No Event     No Event     No Event     No Event
# ...

# %%
calendar.head()
# Out:
#         date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0 2011-01-29     11101   Saturday     1      1  2011  d_1     No Event
# 1 2011-01-30     11101     Sunday     2      1  2011  d_2     No Event
# 2 2011-01-31     11101     Monday     3      1  2011  d_3     No Event
# 3 2011-02-01     11101    Tuesday     4      2  2011  d_4     No Event
# 4 2011-02-02     11101  Wednesday     5      2  2011  d_5     No Event
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI  week  day
# 0     No Event     No Event     No Event        0        0        0     4   29
# 1     No Event     No Event     No Event        0        0        0     4   30
# 2     No Event     No Event     No Event        0        0        0     5   31
# 3     No Event     No Event     No Event        1        1        0     5    1
# 4     No Event     No Event     No Event        1        0        1     5    2

# %%
calendar[
    [
        "date",
        "year",
        "month",
        "week",
        "day",
        "weekday",
        "event_name_1",
        "event_type_1",
        "event_name_2",
        "event_type_2"
    ]
].head(10)
# Out:
#         date  year  month  week  day    weekday event_name_1 event_type_1  \
# 0 2011-01-29  2011      1     4   29   Saturday     No Event     No Event
# 1 2011-01-30  2011      1     4   30     Sunday     No Event     No Event
# 2 2011-01-31  2011      1     5   31     Monday     No Event     No Event
# 3 2011-02-01  2011      2     5    1    Tuesday     No Event     No Event
# 4 2011-02-02  2011      2     5    2  Wednesday     No Event     No Event
# 5 2011-02-03  2011      2     5    3   Thursday     No Event     No Event
# 6 2011-02-04  2011      2     5    4     Friday     No Event     No Event
# 7 2011-02-05  2011      2     5    5   Saturday     No Event     No Event
# 8 2011-02-06  2011      2     5    6     Sunday    SuperBowl     Sporting
# 9 2011-02-07  2011      2     6    7     Monday     No Event     No Event
#
#   event_name_2 event_type_2
# 0     No Event     No Event
# 1     No Event     No Event
# 2     No Event     No Event
# 3     No Event     No Event
# ...

# %%
print("Start date:", calendar["date"].min())
print("End date:", calendar["date"].max())
# Out:
# Start date: 2011-01-29 00:00:00
# End date: 2016-06-19 00:00:00

# %%
date_range = pd.date_range(
    start=calendar["date"].min(),
    end=calendar["date"].max(),
    freq="D"
)

missing_dates = date_range.difference(calendar["date"])

print("Missing dates:", len(missing_dates))
# Out:
# Missing dates: 0

# %%
calendar.isnull().sum()
# Out:
# date            0
# wm_yr_wk        0
# weekday         0
# wday            0
# month           0
# year            0
# d               0
# event_name_1    0
# event_type_1    0
# event_name_2    0
# event_type_2    0
# snap_CA         0
# snap_TX         0
# snap_WI         0
# week            0
# day             0
# dtype: int64

# %%
calendar.to_csv(
    "../data/processed/calendar_cleaned.csv",
    index=False
)

# %% [markdown]
# ## Calendar Cleaning Summary
#
# - Converted the date column to datetime format.
# - Created year, month, week, day and weekday features.
# - Checked the calendar date range and missing dates.
# - Standardized missing event information as "No Event".
# - Preserved the original calendar dataset in the raw folder.
# - Saved the cleaned calendar dataset in the processed folder.
#
# These calendar features will later be used for demand analysis and forecasting.
